# %%
import pandas as pd
import numpy as np
import openpyxl as xl
import numpy as np
import matplotlib.pyplot as plt
import requests


% matplotlib inline

# %%
oil_data_to_load = 'C:/Users/Sal/Desktop/Oil_Project/Eagle_Ford.xlsx'

# %%
# Read Oil Pandas Data Frames
oil_data_df = pd.read_excel(oil_data_to_load)

# %%
oil_data_df.head()
# Out:
#               API  Longitude   Latitude  Bottomhole longitude  \
# 0  42013342710000 -98.332847  28.954002            -98.331992
# 1  42013342730000 -98.455662  28.728584            -98.448771
# 2  42013342780000 -98.470619  28.698830            -98.470619
# 3  42013342790000 -98.450319  28.726421            -98.440780
# 4  42013342850000 -98.439686  28.734653            -98.430205
#
#    Bottomhole latitude Well Number         Lease Name Well Type Permit Type  \
# 0            28.942858          1H       Little L & C       Oil  Horizontal
# 1            28.714850          2H       Peeler Ranch       Oil  Horizontal
# 2            28.698830          1H       Peeler Ranch       Oil  Horizontal
# 3            28.715775         11H       Peeler Ranch       Oil  Horizontal
# 4            28.724640          1H  Peeler Ranch Unit       Oil  Horizontal
#
#   Pad         ...         IP Total (boe/d) EUR Oil (mmbbl) EUR Gas (bcf)  \
# 0  No         ...                    89.77           0.082         0.043
# 1  No         ...                    64.09           0.053         0.156
# 2  No         ...                   287.40           0.172         0.120
# 3  No         ...                    64.09           0.053         0.156
# 4  No         ...                   139.48           0.105         0.119
#
#   EUR Total (mmboe) bi Oil Di Oil (per month) Dmin Oil (per year) bi Gas  \
# 0             0.090   1.59               0.22                 0.1   0.59
# 1             0.081   1.84               0.21                 0.1   2.74
# 2             0.193   0.80               0.21                 0.1   1.40
# 3             0.081   1.84               0.21                 0.1   2.74
# 4             0.125   1.24               0.19                 0.1   1.86
#
#   Di Gas (per month) Dmin Gas (per year)
# 0               0.10                0.05
# 1               1.00                0.05
# 2               0.34                0.05
# 3               1.00                0.05
# 4               1.00                0.05
#
# [5 rows x 72 columns]

# %%
oil_data_df.head()

# Drop all rows with missing information
cleaned_oil_df = oil_data_df.dropna(how='any')

# %%
cleaned_oil_df

# %%
# Show mulitple specific columns--note the extra brackets
cleaned_oil_df[["API", "Longitude","Latitude","Well Number","Well Type","Operator","Sub-play","Well Cost Total (US$)","EUR Total (mmboe)",'Cum365 Gas (mcf)',"Drilling Speed (m/day)"]].head(10)

# %%
#Latitude vs Max Temp Scatter

plt.scatter(cleaned_oil_df["EUR Total (mmboe)"], cleaned_oil_df["Drilling Speed (m/day)"])
plt.title("EUR vs Drilling Speed")
plt.xlabel('EUR')
plt.ylabel('Drilling Speed')
# Out:
# Text(0,0.5,'Drilling Speed')

# %%
#avg rig cost varabilable by subplay
rig_cost = cleaned_oil_df["Rig Cost (US$)"]
measured_depth = cleaned_oil_df["Measured Depth (m)"]

#rig cost by measured depth

rig_cost_by_measured_depth = rig_cost / measured_depth

# %%
#the_cum_sum_well_cost = cost_df.groupby(['Sub-play']).cumsum()['Well Cost Total (US$)']

# %%
# Build cost data frame# Build 
cost_df = pd.DataFrame({
                       'Sub-play':cleaned_oil_df['Sub-play'],
                       'County':cleaned_oil_df['County'],
                       'Well Cost Total (US$)':cleaned_oil_df['Well Cost Total (US$)'],
                       'Rig Cost (US$)':cleaned_oil_df['Rig Cost (US$)'],
                       'Water Cost (US$)':cleaned_oil_df['Water Cost (US$)'],
                       'Proppant Cost (US$)':cleaned_oil_df['Proppant Cost (US$)'],
                       'Pumping Cost (US$)':cleaned_oil_df['Pumping Cost (US$)'],
                       'Other Cost (US$)':cleaned_oil_df['Other Cost (US$)'],
                       'Lateral Length (m)': cleaned_oil_df['Lateral Length (m)'],
                       'Vertical Depth (m)': cleaned_oil_df['Vertical Depth (m)'],
                       'Measured Depth (m)': cleaned_oil_df['Measured Depth (m)'],
                       'EUR Total (mmboe)': cleaned_oil_df['EUR Total (mmboe)'],
                       'Cum365 Total (boe)': cleaned_oil_df['Cum365 Total (boe)'],
                       "Rig cost by depth": rig_cost_by_measured_depth
                       })

# %%
cost_df.head()
# Out:
#          Sub-play    County  Well Cost Total (US$)  Rig Cost (US$)  \
# 36  Karnes Trough  Atascosa              6466931.0        700321.0
# 67  Karnes Trough  Atascosa              5564731.0        600275.0
# 68      Black Oil  Atascosa              3847818.0        659702.0
# 90  Karnes Trough  Atascosa              7150483.0        471216.0
# 93      Black Oil  Atascosa              4930074.0       1130918.0
#
#     Water Cost (US$)  Proppant Cost (US$)  Pumping Cost (US$)  \
# 36          360462.0             317805.0            370149.0
# 67          282989.0             273864.0            294318.0
# 68          178922.0             100949.0            346679.0
# 90          488230.0             178665.0           1177663.0
# 93          214076.0              99206.0            398694.0
#
#     Other Cost (US$)  Lateral Length (m)  Vertical Depth (m)  \
# 36         4390006.0              1909.0              3119.0
# 67         3781883.0              1993.0              3120.0
# 68         2326249.0              1036.0              2632.0
# 90         4542439.0              1280.0              3282.0
# 93         2861825.0              1199.0              2396.0
#
#     Measured Depth (m)  EUR Total (mmboe)  Cum365 Total (boe)  \
# 36              5129.0              0.129             26774.0
# 67              5218.0              0.129             26774.0
# 68              3722.0              0.113             36073.0
# 90              4630.0              0.138             55100.0
# 93              3659.0              0.163             49455.0
#
#     Rig cost by depth
# 36         136.541431
# 67         115.039287
# 68         177.243955
# 90         101.774514
# 93         309.078437

# %%
# Calculate average costs# Calcu 
cost_avg = cost_df.groupby('Sub-play').mean()
cost_avg
# Out:
#                       Well Cost Total (US$)  Rig Cost (US$)  Water Cost (US$)  \
# Sub-play
# Black Oil                      5.897168e+06   562963.671111     492693.080000
# Edwards Condensate             6.468743e+06   514116.937705     410263.655738
# Hawkville Condensate           7.271146e+06   574433.905660     572604.867925
# Karnes Trough                  6.760239e+06   583797.280000     430165.276000
# Maverick Condensate            6.867779e+06   555951.580645     549926.774194
# Maverick Oil                   3.998836e+06   235608.000000     227349.000000
# Southwest Gas                  5.551731e+06   591199.285714     210767.571429
#
#                       Proppant Cost (US$)  Pumping Cost (US$)  \
# Sub-play
# Black Oil                    3.614364e+05        1.499080e+06
# Edwards Condensate           5.026711e+05        1.813465e+06
# Hawkville Condensate         3.868063e+05        1.717162e+06
# Karnes Trough                6.216692e+05        1.786297e+06
# Maverick Condensate          1.096102e+06        8.469642e+05
# Maverick Oil                 1.503250e+05        1.369020e+05
# Southwest Gas                2.186070e+05        6.401450e+05
#
#                       Other Cost (US$)  Lateral Length (m)  \
# Sub-play
# Black Oil                 2.749232e+06         1823.457778
# Edwards Condensate        2.922031e+06         1620.059016
# Hawkville Condensate      3.697000e+06         1885.433962
# Karnes Trough             3.035515e+06         1639.352000
# Maverick Condensate       3.568871e+06         1796.225806
# Maverick Oil              3.043163e+06         1637.000000
# Southwest Gas             3.507704e+06         1406.285714
#
#                       Vertical Depth (m)  Measured Depth (m)  \
# Sub-play
# Black Oil                    2444.773333         4364.368889
# Edwards Condensate           3756.760656         5463.770492
# Hawkville Condensate         3012.358491         4997.132075
# Karnes Trough                3503.228000         5228.192000
# Maverick Condensate          2472.419355         4363.290323
# Maverick Oil                 1534.000000         3257.000000
# Southwest Gas                3651.000000         5131.714286
#
#                       EUR Total (mmboe)  Cum365 Total (boe)  Rig cost by depth
# Sub-play
# Black Oil                      0.271093        90618.595556         130.667828
# Edwards Condensate             0.514420       165526.806557          94.182525
# Hawkville Condensate           0.307792       109749.207547         115.453276
# Karnes Trough                  0.421956       129540.488000         111.176184
# Maverick Condensate            0.480323       176101.483871         126.069287
# Maverick Oil                   0.016000         3505.000000          72.338962
# Southwest Gas                  0.249000       101705.000000         115.266713

# %%
cost_avg.sort_values('Well Cost Total (US$)', ascending = False, inplace = True)
cost_avg
#the_cum_sum_well_cost =[]
the_cum_sum_well_cost = cost_avg.cumsum()['Well Cost Total (US$)']
the_cum_sum_well_cost
# Out:
# Sub-play
# Hawkville Condensate    7.271146e+06
# Maverick Condensate     1.413892e+07
# Karnes Trough           2.089916e+07
# Edwards Condensate      2.736791e+07
# Black Oil               3.326507e+07
# Southwest Gas           3.881681e+07
# Maverick Oil            4.281564e+07
# Name: Well Cost Total (US$), dtype: float64

# %%
cost_avg['Cumulative'] = the_cum_sum_well_cost

# %%
cost_avg
# Out:
#                       Well Cost Total (US$)  Rig Cost (US$)  Water Cost (US$)  \
# Sub-play
# Maverick Oil                   3.998836e+06   235608.000000     227349.000000
# Southwest Gas                  5.551731e+06   591199.285714     210767.571429
# Black Oil                      5.897168e+06   562963.671111     492693.080000
# Edwards Condensate             6.468743e+06   514116.937705     410263.655738
# Karnes Trough                  6.760239e+06   583797.280000     430165.276000
# Maverick Condensate            6.867779e+06   555951.580645     549926.774194
# Hawkville Condensate           7.271146e+06   574433.905660     572604.867925
#
#                       Proppant Cost (US$)  Pumping Cost (US$)  \
# Sub-play
# Maverick Oil                 1.503250e+05        1.369020e+05
# Southwest Gas                2.186070e+05        6.401450e+05
# Black Oil                    3.614364e+05        1.499080e+06
# Edwards Condensate           5.026711e+05        1.813465e+06
# Karnes Trough                6.216692e+05        1.786297e+06
# Maverick Condensate          1.096102e+06        8.469642e+05
# Hawkville Condensate         3.868063e+05        1.717162e+06
#
#                       Other Cost (US$)  Lateral Length (m)  \
# Sub-play
# Maverick Oil              3.043163e+06         1637.000000
# Southwest Gas             3.507704e+06         1406.285714
# Black Oil                 2.749232e+06         1823.457778
# Edwards Condensate        2.922031e+06         1620.059016
# Karnes Trough             3.035515e+06         1639.352000
# Maverick Condensate       3.568871e+06         1796.225806
# Hawkville Condensate      3.697000e+06         1885.433962
#
#                       Vertical Depth (m)  Measured Depth (m)  \
# Sub-play
# Maverick Oil                 1534.000000         3257.000000
# Southwest Gas                3651.000000         5131.714286
# Black Oil                    2444.773333         4364.368889
# Edwards Condensate           3756.760656         5463.770492
# Karnes Trough                3503.228000         5228.192000
# Maverick Condensate          2472.419355         4363.290323
# Hawkville Condensate         3012.358491         4997.132075
#
#                       EUR Total (mmboe)  Cum365 Total (boe)  \
# Sub-play
# Maverick Oil                   0.016000         3505.000000
# Southwest Gas                  0.249000       101705.000000
# Black Oil                      0.271093        90618.595556
# Edwards Condensate             0.514420       165526.806557
# Karnes Trough                  0.421956       129540.488000
# Maverick Condensate            0.480323       176101.483871
# Hawkville Condensate           0.307792       109749.207547
#
#                       Rig cost by depth    Cumulative
# Sub-play
# Maverick Oil                  72.338962  3.998836e+06
# Southwest Gas                115.266713  9.550567e+06
# Black Oil                    130.667828  1.544774e+07
# Edwards Condensate            94.182525  2.191648e+07
# Karnes Trough                111.176184  2.867672e+07
# Maverick Condensate          126.069287  3.554450e+07
# Hawkville Condensate         115.453276  4.281564e+07

# %% [markdown]
# cost_avg

# %%
# Plot total cost cost averages
with plt.style.context('fivethirtyeight'):
    cost_avg['Well Cost Total (US$)'].plot(kind='bar',figsize=(20, 10))

    # Add axis labels and title
    plt.title("Average Well Cost Totals")
    plt.ylabel("US$")

    # Show plot
    plt.xticks(rotation=0)
  # Save Figure
    plt.savefig("C:/Users/Sal/Desktop/avg_sort.png")
    
    plt.show()

# %%
# Plot total cost cost averages
with plt.style.context('fivethirtyeight'):
    cost_avg['Rig cost by depth'].plot(kind='bar',figsize=(20, 10))

    # Add axis labels and title
    plt.title("Rig cost by Measured depth (m)")
    plt.ylabel("US$")

    # Show plot
    plt.xticks(rotation=0)
     # Save Figure
    plt.savefig("C:/Users/Sal/Desktop/rig_sort.png")
    
    plt.show()

# %%
cost_avg
# Out:
#                       Well Cost Total (US$)  Rig Cost (US$)  Water Cost (US$)  \
# Sub-play
# Black Oil                      5.897168e+06   562963.671111     492693.080000
# Edwards Condensate             6.468743e+06   514116.937705     410263.655738
# Hawkville Condensate           7.271146e+06   574433.905660     572604.867925
# Karnes Trough                  6.760239e+06   583797.280000     430165.276000
# Maverick Condensate            6.867779e+06   555951.580645     549926.774194
# Maverick Oil                   3.998836e+06   235608.000000     227349.000000
# Southwest Gas                  5.551731e+06   591199.285714     210767.571429
#
#                       Proppant Cost (US$)  Pumping Cost (US$)  \
# Sub-play
# Black Oil                    3.614364e+05        1.499080e+06
# Edwards Condensate           5.026711e+05        1.813465e+06
# Hawkville Condensate         3.868063e+05        1.717162e+06
# Karnes Trough                6.216692e+05        1.786297e+06
# Maverick Condensate          1.096102e+06        8.469642e+05
# Maverick Oil                 1.503250e+05        1.369020e+05
# Southwest Gas                2.186070e+05        6.401450e+05
#
#                       Other Cost (US$)  Lateral Length (m)  \
# Sub-play
# Black Oil                 2.749232e+06         1823.457778
# Edwards Condensate        2.922031e+06         1620.059016
# Hawkville Condensate      3.697000e+06         1885.433962
# Karnes Trough             3.035515e+06         1639.352000
# Maverick Condensate       3.568871e+06         1796.225806
# Maverick Oil              3.043163e+06         1637.000000
# Southwest Gas             3.507704e+06         1406.285714
#
#                       Vertical Depth (m)  Measured Depth (m)  \
# Sub-play
# Black Oil                    2444.773333         4364.368889
# Edwards Condensate           3756.760656         5463.770492
# Hawkville Condensate         3012.358491         4997.132075
# Karnes Trough                3503.228000         5228.192000
# Maverick Condensate          2472.419355         4363.290323
# Maverick Oil                 1534.000000         3257.000000
# Southwest Gas                3651.000000         5131.714286
#
#                       EUR Total (mmboe)  Cum365 Total (boe)
# Sub-play
# Black Oil                      0.271093        90618.595556
# Edwards Condensate             0.514420       165526.806557
# Hawkville Condensate           0.307792       109749.207547
# Karnes Trough                  0.421956       129540.488000
# Maverick Condensate            0.480323       176101.483871
# Maverick Oil                   0.016000         3505.000000
# Southwest Gas                  0.249000       101705.000000

# %%
#avg rig cost varabilable by subplay
average_rig_cost = cost_avg["Rig Cost (US$)"]
average_measured_depth = cost_avg["Measured Depth (m)"]

#rig cost by measured depth

rig_cost_by_measured_depth = average_rig_cost / average_measured_depth

# %%
rig_cost_by_measured_depth
cost_avg.sort_values('Cum365 Total (boe)', ascending = False, inplace = True)
rig_cost_by_measured_depth

# %%
# Plot total cost cost averages
with plt.style.context('fivethirtyeight'):
    cost_avg['Cum365 Total (boe)'].plot(kind='bar',figsize=(10, 5))

    # Add axis labels and title
    plt.title("Year 1 boe")
    plt.ylabel("US$")

    # Show plot
    plt.show()

# %%
cost_avg
# Out:
#                       Well Cost Total (US$)  Rig Cost (US$)  Water Cost (US$)  \
# Sub-play
# Hawkville Condensate           7.271146e+06   574433.905660     572604.867925
# Maverick Condensate            6.867779e+06   555951.580645     549926.774194
# Karnes Trough                  6.760239e+06   583797.280000     430165.276000
# Edwards Condensate             6.468743e+06   514116.937705     410263.655738
# Black Oil                      5.897168e+06   562963.671111     492693.080000
# Southwest Gas                  5.551731e+06   591199.285714     210767.571429
# Maverick Oil                   3.998836e+06   235608.000000     227349.000000
#
#                       Proppant Cost (US$)  Pumping Cost (US$)  \
# Sub-play
# Hawkville Condensate         3.868063e+05        1.717162e+06
# Maverick Condensate          1.096102e+06        8.469642e+05
# Karnes Trough                6.216692e+05        1.786297e+06
# Edwards Condensate           5.026711e+05        1.813465e+06
# Black Oil                    3.614364e+05        1.499080e+06
# Southwest Gas                2.186070e+05        6.401450e+05
# Maverick Oil                 1.503250e+05        1.369020e+05
#
#                       Other Cost (US$)  Lateral Length (m)  \
# Sub-play
# Hawkville Condensate      3.697000e+06         1885.433962
# Maverick Condensate       3.568871e+06         1796.225806
# Karnes Trough             3.035515e+06         1639.352000
# Edwards Condensate        2.922031e+06         1620.059016
# Black Oil                 2.749232e+06         1823.457778
# Southwest Gas             3.507704e+06         1406.285714
# Maverick Oil              3.043163e+06         1637.000000
#
#                       Vertical Depth (m)  Measured Depth (m)  \
# Sub-play
# Hawkville Condensate         3012.358491         4997.132075
# Maverick Condensate          2472.419355         4363.290323
# Karnes Trough                3503.228000         5228.192000
# Edwards Condensate           3756.760656         5463.770492
# Black Oil                    2444.773333         4364.368889
# Southwest Gas                3651.000000         5131.714286
# Maverick Oil                 1534.000000         3257.000000
#
#                       EUR Total (mmboe)  Cum365 Total (boe)  \
# Sub-play
# Hawkville Condensate           0.307792       109749.207547
# Maverick Condensate            0.480323       176101.483871
# Karnes Trough                  0.421956       129540.488000
# Edwards Condensate             0.514420       165526.806557
# Black Oil                      0.271093        90618.595556
# Southwest Gas                  0.249000       101705.000000
# Maverick Oil                   0.016000         3505.000000
#
#                       Rig cost by depth    Cumulative
# Sub-play
# Hawkville Condensate         115.453276  4.281564e+07
# Maverick Condensate          126.069287  3.554450e+07
# Karnes Trough                111.176184  2.867672e+07
# Edwards Condensate            94.182525  2.191648e+07
# Black Oil                    130.667828  1.544774e+07
# Southwest Gas                115.266713  9.550567e+06
# Maverick Oil                  72.338962  3.998836e+06

# %%
# Plot total cost averages
with plt.style.context('fivethirtyeight'):
    cost_avg['Well Cost Total (US$)'].plot(kind='bar',figsize=(20, 10))

    # Add axis labels and title
    plt.title("Average Well Cost Totals")
    plt.ylabel("US$")

    plt.cost_avg['Cumulative Well cost']
    # Show plot
    plt.xticks(rotation=0)
  # Save Figure
    plt.savefig("C:/Users/Sal/Desktop/avg_sort.png")
    
    plt.show()

# %%
weights=[]
weights =cost_avg["Rig Cost (US$)"]
cumu_weights=[]
cumu_weights =cost_avg["Cumulative"]

# %%
# lefthand edge of each bar
left = np.arange(len(weights))
fig, ax = plt.subplots(1, 1)
ax.bar(left, weights, 1)
ax.set_xticks(left)
ax.set_xticklabels(labels,fontsize=10, fontweight='bold', rotation=35, color='darkblue')
ax.plot(cumu_weights)
